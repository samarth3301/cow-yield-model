# %% [markdown]
# # EDA and Training
# This notebook contains exploratory analysis and the training pipeline.

# %%
import pandas as pd
from src.data_loader import load_data

df = load_data('data/cattle_milk_yield_health_dummy.csv')
df.head()
